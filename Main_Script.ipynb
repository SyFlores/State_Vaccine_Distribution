# %% [markdown]
# ### Define all packages and modules needed for the notebook.

# %%
import pandas as pd

# %% [markdown]
# ### Read in raw datasets

# %%
# Read in the "Distribution of COVID-19 deaths and populations, by jurisdiction, age, and race and Hispanic origin" dataset
impacts_file = 'Data/Input/raw_covid_impacts.csv'
impacts_df = pd.read_csv(impacts_file)

# Read in the "COVID-19 Vaccine Distribution Allocations by Jurisdiction" datasets for:

# Janssen
janssen_file = 'Data/Input/raw_janssen.csv'
janssen_df = pd.read_csv(janssen_file)

# Moderna
moderna_file = 'Data/Input/raw_moderna.csv'
moderna_df = pd.read_csv(moderna_file)

# Pfizer
pfizer_file = 'Data/Input/raw_pfizer.csv'
pfizer_df = pd.read_csv(pfizer_file)

# %% [markdown]
# ## Cleaning the COVID-19 Impacts dataframe

# %% [markdown]
# ### Remove 'United States' and 'New York City' data shown in the 'State' field
# - The way that we are intending to integrate supplementary data, 'United States' serves as a unusable total for all states
# - This only obfuscates the compatibility of the data, and can be queried if truly desired anyhow

# %%
impacts_df1 = impacts_df[
    (impacts_df["State"] != "United States")
    & (impacts_df["State"] != "New York City")
]

# %% [markdown]
# ### Remove 'All ages, unadjusted' and 'All ages, standardized'  data shown in the AgeGroup field
# - The way we are intending to integrate supplementary data, these would complicate querying
# - The raw unadjusted values can be queried if deemed necessary
# - the standardized values can be added back if there is a particular usefulness in using this data

# %%
impacts_df2 = impacts_df1[
    (impacts_df1["AgeGroup"] != "All ages, unadjusted")
    & (impacts_df1["AgeGroup"] != "All ages, standardized")
]

# %% [markdown]
# ### Drop the 'Data as of', 'Start Date', and 'End Date 'columns
# - As these columns contain the same data point, we can safely remove
# - We will specify the details of this dataframe in the README

# %%
impacts_df3 = impacts_df2.drop(columns=['Data as of', 'Start Date', 'End Date'])

# %% [markdown]
# ### Rename columns to be more SQL friendly
# - Remove all spaces, replace with underscores
# - Limit use of any special characters
# - Reduce length where appropriate

# %%
# Define the dictionary used to rename each column
column_rename = {
    "State" : "state"
    ,"Race/Hispanic origin" : "race_hispanic"
    ,"Count of COVID-19 deaths" : "death_count"
    ,"Distribution of COVID-19 deaths (%)" : "death_percent"
    ,"Unweighted distribution of population (%)" : "unweighted_population_percent"
    ,"Weighted distribution of population (%)" : "weighted_population_percent"
    ,"Difference between COVID-19 and unweighted population %" : "diff_death_unweighted_population_percent"
    ,"Difference between COVID-19 and weighted population %" : "diff_death_weighted_population_percent"
    ,"AgeGroup" : "age_group"
    ,"Suppression" : "suppression"
}

# %%
# Invoke the the column_rename dictionary to change column names
impacts_df4 = impacts_df3.rename(columns = column_rename)

# %% [markdown]
# ### Reorder data to improve visibility
# - Column priority will be the following: state, age_group, race_hispanic

# %%
impacts_df5 = impacts_df4.sort_values(['state', 'age_group', 'race_hispanic'])

# %% [markdown]
# ### Reset index values
# - Since we've removed rows and reordered data we'll have to reset the index
# - This will make the migration into SQL much better

# %%
impacts_df6 = impacts_df5.reset_index(drop=True)

# %% [markdown]
# ### View sample of the finished dataframe

# %%
impacts_df6.head(50)
# Out:
#       state                                      race_hispanic  death_count  \
# 0   Alabama                                           Hispanic          NaN
# 1   Alabama      Non-Hispanic American Indian or Alaska Native          0.0
# 2   Alabama                                 Non-Hispanic Asian          0.0
# 3   Alabama                                 Non-Hispanic Black          NaN
# 4   Alabama  Non-Hispanic Native Hawaiian or Other Pacific ...          0.0
# 5   Alabama                                 Non-Hispanic White          NaN
# 6   Alabama                                              Other          0.0
# 7   Alabama                                           Hispanic          NaN
# 8   Alabama      Non-Hispanic American Indian or Alaska Native          0.0
# 9   Alabama                                 Non-Hispanic Asian          0.0
# 10  Alabama                                 Non-Hispanic Black         36.0
# 11  Alabama  Non-Hispanic Native Hawaiian or Other Pacific ...          0.0
# 12  Alabama                                 Non-Hispanic White         20.0
# 13  Alabama                                              Other          NaN
# 14  Alabama                                           Hispanic         10.0
# 15  Alabama      Non-Hispanic American Indian or Alaska Native          0.0
# 16  Alabama                                 Non-Hispanic Asian          NaN
# 17  Alabama                                 Non-Hispanic Black        115.0
# 18  Alabama  Non-Hispanic Native Hawaiian or Other Pacific ...          0.0
# 19  Alabama                                 Non-Hispanic White         62.0
# 20  Alabama                                              Other          0.0
# 21  Alabama                                           Hispanic         46.0
# 22  Alabama      Non-Hispanic American Indian or Alaska Native          NaN
# 23  Alabama                                 Non-Hispanic Asian          NaN
# 24  Alabama                                 Non-Hispanic Black        239.0
# 25  Alabama  Non-Hispanic Native Hawaiian or Other Pacific ...          0.0
# 26  Alabama                                 Non-Hispanic White        235.0
# 27  Alabama                                              Other          NaN
# 28  Alabama                                           Hispanic         49.0
# 29  Alabama      Non-Hispanic American Indian or Alaska Native          NaN
# 30  Alabama                                 Non-Hispanic Asian          NaN
# 31  Alabama                                 Non-Hispanic Black        562.0
# 32  Alabama  Non-Hispanic Native Hawaiian or Other Pacific ...          0.0
# 33  Alabama                                 Non-Hispanic White        731.0
# 34  Alabama                                              Other          NaN
# 35  Alabama                                           Hispanic         33.0
# 36  Alabama      Non-Hispanic American Indian or Alaska Native          NaN
# 37  Alabama                                 Non-Hispanic Asian         14.0
# 38  Alabama                                 Non-Hispanic Black        826.0
# 39  Alabama  Non-Hispanic Native Hawaiian or Other Pacific ...          0.0
# 40  Alabama                                 Non-Hispanic White       1643.0
# 41  Alabama                                              Other          NaN
# 42  Alabama                                           Hispanic         19.0
# 43  Alabama      Non-Hispanic American Indian or Alaska Native          NaN
# 44  Alabama                                 Non-Hispanic Asian         13.0
# 45  Alabama                                 Non-Hispanic Black        632.0
# 46  Alabama  Non-Hispanic Native Hawaiian or Other Pacific ...          0.0
# 47  Alabama                                 Non-Hispanic White       2196.0
# 48  Alabama                                              Other          NaN
# 49  Alabama                                           Hispanic         12.0
#
#     death_percent  unweighted_population_percent  weighted_population_percent  \
# 0             NaN                            7.3                          6.6
# 1             0.0                            0.5                          0.3
# 2             0.0                            1.5                          1.9
# 3             NaN                           29.5                         40.0
# 4             0.0                            0.1                          0.1
# 5             NaN                           58.1                         48.4
# 6             0.0                            3.0                          2.8
# 7             NaN                            5.0                          4.4
# 8             0.0                            0.6                          0.4
# 9             0.0                            1.8                          2.3
# 10           57.1                           30.1                         39.3
# 11            0.0                            0.1                          0.0
# 12           31.7                           61.1                         52.2
# 13            NaN                            1.4                          1.3
# 14            5.3                            5.5                          4.7
# 15            0.0                            0.6                          0.4
# 16            NaN                            2.0                          2.5
# 17           61.2                           27.6                         37.4
# 18            0.0                            0.1                          0.0
# 19           33.0                           63.2                         53.8
# 20            0.0                            1.0                          1.0
# 21            8.7                            3.6                          3.3
# 22            NaN                            0.6                          0.4
# 23            NaN                            1.8                          2.4
# 24           45.4                           25.2                         35.1
# 25            0.0                            0.0                          0.0
# 26           44.6                           67.9                         57.9
# 27            NaN                            0.9                          0.9
# 28            3.6                            2.0                          1.9
# 29            NaN                            0.7                          0.4
# 30            NaN                            1.2                          1.5
# 31           41.4                           24.7                         34.9
# 32            0.0                            0.0                          0.0
# 33           53.9                           70.6                         60.5
# 34            NaN                            0.8                          0.7
# 35            1.3                            1.2                          1.1
# 36            NaN                            0.6                          0.4
# 37            0.6                            1.0                          1.2
# 38           32.7                           21.4                         31.1
# 39            0.0                            0.0                          0.0
# 40           65.1                           75.0                         65.5
# 41            NaN                            0.8                          0.6
# 42            0.7                            1.1                          1.0
# 43            NaN                            0.5                          0.4
# 44            0.5                            0.7                          1.0
# 45           22.0                           17.2                         24.8
# 46            0.0                            0.0                          0.0
# 47           76.6                           79.7                         72.2
# 48            NaN                            0.7                          0.5
# 49            0.5                            1.4                          1.2
#
#     diff_death_unweighted_population_percent  \
# 0                                        NaN
# 1                                       -0.5
# 2                                       -1.5
# 3                                        NaN
# 4                                       -0.1
# 5                                        NaN
# 6                                       -3.0
# 7                                        NaN
# 8                                       -0.6
# 9                                       -1.8
# 10                                      27.0
# 11                                      -0.1
# 12                                     -29.4
# 13                                       NaN
# 14                                      -0.2
# 15                                      -0.6
# 16                                       NaN
# 17                                      33.6
# 18                                      -0.1
# 19                                     -30.2
# 20                                      -1.0
# 21                                       5.1
# 22                                       NaN
# 23                                       NaN
# 24                                      20.2
# 25                                       0.0
# 26                                     -23.3
# 27                                       NaN
# 28                                       1.6
# 29                                       NaN
# 30                                       NaN
# 31                                      16.7
# 32                                       0.0
# 33                                     -16.7
# 34                                       NaN
# 35                                       0.1
# 36                                       NaN
# 37                                      -0.4
# 38                                      11.3
# 39                                       0.0
# 40                                      -9.9
# 41                                       NaN
# 42                                      -0.4
# 43                                       NaN
# 44                                      -0.2
# 45                                       4.8
# 46                                       0.0
# 47                                      -3.1
# 48                                       NaN
# 49                                      -0.9
#
#     diff_death_weighted_population_percent          age_group  \
# 0                                      NaN         0-24 years
# 1                                     -0.3         0-24 years
# 2                                     -1.9         0-24 years
# 3                                      NaN         0-24 years
# 4                                     -0.1         0-24 years
# 5                                      NaN         0-24 years
# 6                                     -2.8         0-24 years
# 7                                      NaN        25-34 years
# 8                                     -0.4        25-34 years
# 9                                     -2.3        25-34 years
# 10                                    17.8        25-34 years
# 11                                     0.0        25-34 years
# 12                                   -20.5        25-34 years
# 13                                     NaN        25-34 years
# 14                                     0.6        35-44 years
# 15                                    -0.4        35-44 years
# 16                                     NaN        35-44 years
# 17                                    23.8        35-44 years
# 18                                     0.0        35-44 years
# 19                                   -20.8        35-44 years
# 20                                    -1.0        35-44 years
# 21                                     5.4        45-54 years
# 22                                     NaN        45-54 years
# 23                                     NaN        45-54 years
# 24                                    10.3        45-54 years
# 25                                     0.0        45-54 years
# 26                                   -13.3        45-54 years
# 27                                     NaN        45-54 years
# 28                                     1.7        55-64 years
# 29                                     NaN        55-64 years
# 30                                     NaN        55-64 years
# 31                                     6.5        55-64 years
# 32                                     0.0        55-64 years
# 33                                    -6.6        55-64 years
# 34                                     NaN        55-64 years
# 35                                     0.2        65-74 years
# 36                                     NaN        65-74 years
# 37                                    -0.6        65-74 years
# 38                                     1.6        65-74 years
# 39                                     0.0        65-74 years
# 40                                    -0.4        65-74 years
# 41                                     NaN        65-74 years
# 42                                    -0.3        75-84 years
# 43                                     NaN        75-84 years
# 44                                    -0.5        75-84 years
# 45                                    -2.8        75-84 years
# 46                                     0.0        75-84 years
# 47                                     4.4        75-84 years
# 48                                     NaN        75-84 years
# 49                                    -0.7  85 years and over
#
#                 suppression
# 0   Suppressed (counts <10)
# 1                       NaN
# 2                       NaN
# 3   Suppressed (counts <10)
# 4                       NaN
# 5   Suppressed (counts <10)
# 6                       NaN
# 7   Suppressed (counts <10)
# 8                       NaN
# 9                       NaN
# 10                      NaN
# 11                      NaN
# 12                      NaN
# 13  Suppressed (counts <10)
# 14                      NaN
# 15                      NaN
# 16  Suppressed (counts <10)
# 17                      NaN
# 18                      NaN
# 19                      NaN
# 20                      NaN
# 21                      NaN
# 22  Suppressed (counts <10)
# 23  Suppressed (counts <10)
# 24                      NaN
# 25                      NaN
# 26                      NaN
# 27  Suppressed (counts <10)
# 28                      NaN
# 29  Suppressed (counts <10)
# 30  Suppressed (counts <10)
# 31                      NaN
# 32                      NaN
# 33                      NaN
# 34  Suppressed (counts <10)
# 35                      NaN
# 36  Suppressed (counts <10)
# 37                      NaN
# 38                      NaN
# 39                      NaN
# 40                      NaN
# 41  Suppressed (counts <10)
# 42                      NaN
# 43  Suppressed (counts <10)
# 44                      NaN
# 45                      NaN
# 46                      NaN
# 47                      NaN
# 48  Suppressed (counts <10)
# 49                      NaN

# %% [markdown]
# ## Cleaning the COVID-19 Distribution dataframes

# %%
# Delete rows for regions that don't show up in state:
    # American Samoa, Chicago, Federal Entities, Guam, Mariana Islands, Marshall Islands, 
    # Micronesia, Palau, Puerto Rico, U.S. Virgin Islands
# Rename columns to specify the type of vaccine X
# Sort by Week of Allocations and Jurisdiction in that priority Y
# Reset indexes
# Add data together - horizontally YAfter
# Remove extra columns
# Convert empty/NaN cells (Moderna and Janssen) to 0

# %% [markdown]
# ### Rename columns for Janssen, Moderna and Pfizer
# - To prepare for the merging of data, distinguish columns with the same name
# - Since pfizer_df will serve as the base, we won't have to rename it's 'Jurisdiction' and Week of 'Allocation' field to specifiy Pfizer

# %%
# Define the dictionaries used to rename the columns in the vaccine datasets
janssen = "janssen_"
moderna = "moderna_"
pfizer = "pfizer_"

janssen_rename = {
    "Jurisdiction" : "jurisdiction"
    ,"Week of Allocations" : janssen + "allocation_week"
    ,"1st Dose Allocations" : janssen + "1st_dose_allocation"
}

moderna_rename = {
    "Jurisdiction" : "jurisdiction"
    ,"Week of Allocations" : moderna + "allocation_week"
    ,"1st Dose Allocations" : moderna + "1st_dose_allocation"
    ,"2nd Dose Allocations" : moderna + "2nd_dose_allocation"
}

pfizer_rename = {
    "Jurisdiction" : "jurisdiction"
    ,"Week of Allocations" : pfizer + "allocation_week"
    ,"1st Dose Allocations" : pfizer + "1st_dose_allocation"
    ,"2nd Dose Allocations" : pfizer + "2nd_dose_allocation"
}

# %%
janssen_df1 = janssen_df.rename(columns = janssen_rename)

moderna_df1 = moderna_df.rename(columns = moderna_rename)

pfizer_df1 = pfizer_df.rename(columns = pfizer_rename)

# %% [markdown]
# ### Create GroupBy DataFrames taking sums on 'Jurisdiction'
# - We are looking to create a singular instance for each jurisdiction, taking the totals for each column
# - We will do this by taking the sum for 1st dose and 2nd dose allocations

# %%
group_janssen = janssen_df1.groupby(["jurisdiction"])
janssen_first_sum = group_janssen["janssen_1st_dose_allocation"].sum()

group_moderna = moderna_df1.groupby(["jurisdiction"])
moderna_first_sum = group_moderna["moderna_1st_dose_allocation"].sum()
moderna_second_sum = group_moderna["moderna_2nd_dose_allocation"].sum()

group_pfizer = pfizer_df1.groupby(["jurisdiction"])
pfizer_first_sum = group_pfizer["pfizer_1st_dose_allocation"].sum()
pfizer_second_sum = group_pfizer["pfizer_2nd_dose_allocation"].sum()

# %%
group_janssen_df = pd.DataFrame({
    "janssen_1st_dose_allocation" : janssen_first_sum
})
# group_janssen_df.reset_index(level=0, inplace=True)


group_moderna_df = pd.DataFrame({
    "moderna_1st_dose_allocation" : moderna_first_sum
    ,"moderna_2nd_dose_allocation" : moderna_second_sum
})
# group_moderna_df.reset_index(level=0, inplace=True)


group_pfizer_df = pd.DataFrame({
    "pfizer_1st_dose_allocation" : pfizer_first_sum
    ,"pfizer_2nd_dose_allocation" : pfizer_second_sum
})
# group_pfizer_df.reset_index(level=0, inplace=True)

# %%
vaccine_allocation = pd.concat([group_pfizer_df, group_moderna_df, group_janssen_df], axis=1)
vaccine_allocation.reset_index(level=0, inplace=True)

vaccine_allocation["complete_vaccines"] = vaccine_allocation.pfizer_1st_dose_allocation + vaccine_allocation.moderna_1st_dose_allocation + vaccine_allocation.janssen_1st_dose_allocation
# Out:
#       jurisdiction  pfizer_1st_dose_allocation  pfizer_2nd_dose_allocation  \
# 0          Alabama                      613860                      613860
# 1           Alaska                      143520                      143520
# 2   American Samoa                       30810                           0
# 3          Arizona                      871260                      871260
# 4         Arkansas                      377130                      377130
# ..             ...                         ...                         ...
# 58        Virginia                     1065285                     1065285
# 59      Washington                      948285                      948285
# 60   West Virginia                      240630                      240630
# 61       Wisconsin                      739830                      739830
# 62         Wyoming                       78390                       78390
#
#     moderna_1st_dose_allocation  moderna_2nd_dose_allocation  \
# 0                        603400                       603400
# 1                        134000                       134000
# 2                         12400                            0
# 3                        855200                       855200
# 4                        366000                       366000
# ..                          ...                          ...
# 58                      1047700                      1047700
# 59                       916400                       916400
# 60                       233900                       233900
# 61                       722700                       722700
# 62                        72200                        72200
#
#     janssen_1st_dose_allocation  complete_vaccines
# 0                         51300            1268560
# 1                         11500             289020
# 2                           600              43810
# 3                         72600            1799060
# 4                         31200             774330
# ..                          ...                ...
# 58                        88900            2201885
# 59                        77700            1942385
# 60                        19900             494430
# 61                        61400            1523930
# 62                         6200             156790
#
# [63 rows x 7 columns]

# %% [markdown]
# ### Remove row data shown in the 'Jurisdiction' field
# - Can delete rows for **American Samoa, Chicago, Federal Entities, Guam, Mariana Islands, Marshall Islands, Micronesia, New York City, Palau, Puerto Rico,** and **U.S. Virgin Islands** as it doesn't have a match with the impacts dataframe
# - The use of these jurisdictions will cause more confusion than not, such as New York City being a subset of New York

# %%
vaccine_allocation.head(63)
# Out:
#       jurisdiction  pfizer_1st_dose_allocation  pfizer_2nd_dose_allocation  \
# 0          Alabama                      613860                      613860
# 1           Alaska                      143520                      143520
# 2   American Samoa                       30810                           0
# 3          Arizona                      871260                      871260
# 4         Arkansas                      377130                      377130
# ..             ...                         ...                         ...
# 58        Virginia                     1065285                     1065285
# 59      Washington                      948285                      948285
# 60   West Virginia                      240630                      240630
# 61       Wisconsin                      739830                      739830
# 62         Wyoming                       78390                       78390
#
#     moderna_1st_dose_allocation  moderna_2nd_dose_allocation  \
# 0                        603400                       603400
# 1                        134000                       134000
# 2                         12400                            0
# 3                        855200                       855200
# 4                        366000                       366000
# ..                          ...                          ...
# 58                      1047700                      1047700
# 59                       916400                       916400
# 60                       233900                       233900
# 61                       722700                       722700
# 62                        72200                        72200
#
#     janssen_1st_dose_allocation  complete_vaccines
# 0                         51300            1268560
# 1                         11500             289020
# 2                           600              43810
# 3                         72600            1799060
# 4                         31200             774330
# ..                          ...                ...
# 58                        88900            2201885
# 59                        77700            1942385
# 60                        19900             494430
# 61                        61400            1523930
# 62                         6200             156790
#
# [63 rows x 7 columns]
